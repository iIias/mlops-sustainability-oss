# %% [markdown]
# # Initialize DVC and Start Tracking Merged Data

# %% [markdown]
# - Clean data
#     - Drop columns not required for training
#     - Drop rows with null valus where it makes sense
#     (river discharge may be NaN where there is no river. It makes sense to keep these rows for the model to learn where rivers are)
# - Think about whether or not to have separate notebooks for new data retrievals and prep
# - Version Control the data
# - Train test splitting
# - Version control again??

# %%
# Install required packages.
# TODO: Create IBM Cloud Software Configuration for those
# !pip install ibm-cos-sdk ibm_watson_studio_pipelines

# %%
from botocore.client import Config
from sklearn.model_selection import train_test_split
from dataclasses import dataclass
import numpy as np
import pandas as pd

from ibm_watson_studio_pipelines import WSPipelines
import ibm_boto3

import logging
import os, types
import warnings

warnings.filterwarnings("ignore")

# %%
# !pip install 'dvc[s3]' # dvc[all] alternatively, however, COS is covered by S3
# Out:
# zsh:1: /Users/ennmouri/csm/mlops-sustainability-oss/venv/bin/pip: bad interpreter: /Users/ennmouri/csm/mlops-sustainability/venv/bin/python3: no such file or directory
# Requirement already satisfied: dvc[s3] in /opt/homebrew/lib/python3.10/site-packages (2.58.1)
# Requirement already satisfied: pydot>=1.2.4 in /opt/homebrew/lib/python3.10/site-packages (from dvc[s3]) (1.4.2)
# Requirement already satisfied: funcy>=1.14 in /opt/homebrew/lib/python3.10/site-packages (from dvc[s3]) (2.0)
# Requirement already satisfied: networkx>=2.5 in /opt/homebrew/lib/python3.10/site-packages (from dvc[s3]) (3.1)
# Requirement already satisfied: pathspec>=0.10.3 in /opt/homebrew/lib/python3.10/site-packages (from dvc[s3]) (0.11.1)
# Requirement already satisfied: shtab<2,>=1.3.4 in /opt/homebrew/lib/python3.10/site-packages (from dvc[s3]) (1.6.1)
# Requirement already satisfied: requests>=2.22 in /opt/homebrew/lib/python3.10/site-packages (from dvc[s3]) (2.28.2)
# Requirement already satisfied: iterative-telemetry>=0.0.7 in /opt/homebrew/lib/python3.10/site-packages (from dvc[s3]) (0.0.8)
# Requirement already satisfied: pygtrie>=2.3.2 in /opt/homebrew/lib/python3.10/site-packages (from dvc[s3]) (2.5.0)
# Requirement already satisfied: ruamel.yaml>=0.17.11 in /opt/homebrew/lib/python3.10/site-packages (from dvc[s3]) (0.17.28)
# Requirement already satisfied: psutil>=5.8 in /Users/ennmouri/Library/Python/3.10/lib/python/site-packages (from dvc[s3]) (5.9.4)
# Requirement already satisfied: dvc-task<1,>=0.2.1 in /opt/homebrew/lib/python3.10/site-packages (from dvc[s3]) (0.2.1)
# Requirement already satisfied: colorama>=0.3.9 in /opt/homebrew/lib/python3.10/site-packages (from dvc[s3]) (0.4.6)
# Requirement already satisfied: flufl.lock>=5 in /opt/homebrew/lib/python3.10/site-packages (from dvc[s3]) (7.1.1)
# Requirement already satisfied: scmrepo<2,>=1.0.0 in /opt/homebrew/lib/python3.10/site-packages (from dvc[s3]) (1.0.3)
# Requirement already satisfied: tqdm<5,>=4.63.1 in /opt/homebrew/lib/python3.10/site-packages (from dvc[s3]) (4.64.0)
# Requirement already satisfied: flatten-dict<1,>=0.4.1 in /opt/homebrew/lib/python3.10/site-packages (from dvc[s3]) (0.4.2)
# Requirement already satisfied: platformdirs<4,>=3.1.1 in /opt/homebrew/lib/python3.10/site-packages (from dvc[s3]) (3.5.1)
# Requirement already satisfied: dpath<3,>=2.1.0 in /opt/homebrew/lib/python3.10/site-packages (from dvc[s3]) (2.1.6)
# Requirement already satisfied: tomlkit>=0.11.1 in /opt/homebrew/lib/python3.10/site-packages (from dvc[s3]) (0.11.8)
# Requirement already satisfied: voluptuous>=0.11.7 in /opt/homebrew/lib/python3.10/site-packages (from dvc[s3]) (0.13.1)
# Requirement already satisfied: packaging>=19 in /opt/homebrew/lib/python3.10/site-packages (from dvc[s3]) (21.3)
# Requirement already satisfied: tabulate>=0.8.7 in /opt/homebrew/lib/python3.10/site-packages (from dvc[s3]) (0.9.0)
# Requirement already satisfied: dvc-data<0.52,>=0.51.0 in /opt/homebrew/lib/python3.10/site-packages (from dvc[s3]) (0.51.0)
# Requirement already satisfied: distro>=1.3 in /opt/homebrew/lib/python3.10/site-packages (from dvc[s3]) (1.8.0)
# Requirement already satisfied: zc.lockfile>=1.2.1 in /opt/homebrew/lib/python3.10/site-packages (from dvc[s3]) (3.0.post1)
# Requirement already satisfied: rich>=12 in /opt/homebrew/lib/python3.10/site-packages (from dvc[s3]) (13.3.5)
# Requirement already satisfied: hydra-core>=1.1 in /opt/homebrew/lib/python3.10/site-packages (from dvc[s3]) (1.3.2)
# Requirement already satisfied: grandalf<1,>=0.7 in /opt/homebrew/lib/python3.10/site-packages (from dvc[s3]) (0.8)
# Requirement already satisfied: configobj>=5.0.6 in /opt/homebrew/lib/python3.10/site-packages (from dvc[s3]) (5.0.8)
# Requirement already satisfied: shortuuid>=0.5 in /opt/homebrew/lib/python3.10/site-packages (from dvc[s3]) (1.0.11)
# Requirement already satisfied: dvc-studio-client<1,>=0.9.2 in /opt/homebrew/lib/python3.10/site-packages (from dvc[s3]) (0.10.0)
# Requirement already satisfied: dvc-http>=2.29.0 in /opt/homebrew/lib/python3.10/site-packages (from dvc[s3]) (2.30.2)
# Requirement already satisfied: dvc-render<1,>=0.3.1 in /opt/homebrew/lib/python3.10/site-packages (from dvc[s3]) (0.5.3)
# Requirement already satisfied: pyparsing>=2.4.7 in /opt/homebrew/lib/python3.10/site-packages (from dvc[s3]) (3.0.9)
# Requirement already satisfied: dvc-s3==2.22.0 in /opt/homebrew/lib/python3.10/site-packages (from dvc[s3]) (2.22.0)
# Requirement already satisfied: aiobotocore[boto3]>1.0.1 in /opt/homebrew/lib/python3.10/site-packages (from dvc-s3==2.22.0->dvc[s3]) (2.5.0)
# Requirement already satisfied: s3fs>=2022.02.0 in /opt/homebrew/lib/python3.10/site-packages (from dvc-s3==2.22.0->dvc[s3]) (2023.5.0)
# Requirement already satisfied: six in /opt/homebrew/lib/python3.10/site-packages (from configobj>=5.0.6->dvc[s3]) (1.16.0)
# Requirement already satisfied: dictdiffer>=0.8.1 in /opt/homebrew/lib/python3.10/site-packages (from dvc-data<0.52,>=0.51.0->dvc[s3]) (0.9.0)
# Requirement already satisfied: sqltrie<1,>=0.3.1 in /opt/homebrew/lib/python3.10/site-packages (from dvc-data<0.52,>=0.51.0->dvc[s3]) (0.3.1)
# Requirement already satisfied: diskcache>=5.2.1 in /opt/homebrew/lib/python3.10/site-packages (from dvc-data<0.52,>=0.51.0->dvc[s3]) (5.6.1)
# Requirement already satisfied: attrs>=21.3.0 in /Users/ennmouri/Library/Python/3.10/lib/python/site-packages (from dvc-data<0.52,>=0.51.0->dvc[s3]) (22.2.0)
# Requirement already satisfied: nanotime>=0.5.2 in /opt/homebrew/lib/python3.10/site-packages (from dvc-data<0.52,>=0.51.0->dvc[s3]) (0.5.2)
# Requirement already satisfied: dvc-objects<1,>=0.22.0 in /opt/homebrew/lib/python3.10/site-packages (from dvc-data<0.52,>=0.51.0->dvc[s3]) (0.22.0)
# Requirement already satisfied: aiohttp-retry>=2.5.0 in /opt/homebrew/lib/python3.10/site-packages (from dvc-http>=2.29.0->dvc[s3]) (2.8.3)
# Requirement already satisfied: fsspec[http] in /opt/homebrew/lib/python3.10/site-packages (from dvc-http>=2.29.0->dvc[s3]) (2023.5.0)
# Requirement already satisfied: dulwich in /opt/homebrew/lib/python3.10/site-packages (from dvc-studio-client<1,>=0.9.2->dvc[s3]) (0.21.5)
# Requirement already satisfied: celery<6,>=5.2.0 in /opt/homebrew/lib/python3.10/site-packages (from dvc-task<1,>=0.2.1->dvc[s3]) (5.2.7)
# Requirement already satisfied: kombu<6,>=5.2.0 in /opt/homebrew/lib/python3.10/site-packages (from dvc-task<1,>=0.2.1->dvc[s3]) (5.2.4)
# Requirement already satisfied: atpublic>=2.3 in /opt/homebrew/lib/python3.10/site-packages (from flufl.lock>=5->dvc[s3]) (3.1.1)
# Requirement already satisfied: omegaconf<2.4,>=2.2 in /opt/homebrew/lib/python3.10/site-packages (from hydra-core>=1.1->dvc[s3]) (2.3.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /opt/homebrew/lib/python3.10/site-packages (from hydra-core>=1.1->dvc[s3]) (4.9.3)
# Requirement already satisfied: filelock in /opt/homebrew/lib/python3.10/site-packages (from iterative-telemetry>=0.0.7->dvc[s3]) (3.12.0)
# Requirement already satisfied: appdirs in /opt/homebrew/lib/python3.10/site-packages (from iterative-telemetry>=0.0.7->dvc[s3]) (1.4.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/lib/python3.10/site-packages (from requests>=2.22->dvc[s3]) (2022.12.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/lib/python3.10/site-packages (from requests>=2.22->dvc[s3]) (3.0.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/homebrew/lib/python3.10/site-packages (from requests>=2.22->dvc[s3]) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/lib/python3.10/site-packages (from requests>=2.22->dvc[s3]) (3.4)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /opt/homebrew/lib/python3.10/site-packages (from rich>=12->dvc[s3]) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/ennmouri/Library/Python/3.10/lib/python/site-packages (from rich>=12->dvc[s3]) (2.14.0)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /opt/homebrew/lib/python3.10/site-packages (from ruamel.yaml>=0.17.11->dvc[s3]) (0.2.7)
# Requirement already satisfied: asyncssh<3,>=2.13.1 in /opt/homebrew/lib/python3.10/site-packages (from scmrepo<2,>=1.0.0->dvc[s3]) (2.13.1)
# Requirement already satisfied: gitpython>3 in /opt/homebrew/lib/python3.10/site-packages (from scmrepo<2,>=1.0.0->dvc[s3]) (3.1.30)
# Requirement already satisfied: pygit2>=1.10.0 in /opt/homebrew/lib/python3.10/site-packages (from scmrepo<2,>=1.0.0->dvc[s3]) (1.12.1)
# Requirement already satisfied: setuptools in /opt/homebrew/lib/python3.10/site-packages (from zc.lockfile>=1.2.1->dvc[s3]) (67.2.0)
# Requirement already satisfied: aioitertools>=0.5.1 in /opt/homebrew/lib/python3.10/site-packages (from aiobotocore[boto3]>1.0.1->dvc-s3==2.22.0->dvc[s3]) (0.11.0)
# Requirement already satisfied: wrapt>=1.10.10 in /opt/homebrew/lib/python3.10/site-packages (from aiobotocore[boto3]>1.0.1->dvc-s3==2.22.0->dvc[s3]) (1.15.0)
# Requirement already satisfied: aiohttp>=3.3.1 in /opt/homebrew/lib/python3.10/site-packages (from aiobotocore[boto3]>1.0.1->dvc-s3==2.22.0->dvc[s3]) (3.8.4)
# Requirement already satisfied: botocore<1.29.77,>=1.29.76 in /opt/homebrew/lib/python3.10/site-packages (from aiobotocore[boto3]>1.0.1->dvc-s3==2.22.0->dvc[s3]) (1.29.76)
# Requirement already satisfied: boto3<1.26.77,>=1.26.76 in /opt/homebrew/lib/python3.10/site-packages (from aiobotocore[boto3]>1.0.1->dvc-s3==2.22.0->dvc[s3]) (1.26.76)
# Requirement already satisfied: typing-extensions>=3.6 in /opt/homebrew/lib/python3.10/site-packages (from asyncssh<3,>=2.13.1->scmrepo<2,>=1.0.0->dvc[s3]) (4.4.0)
# Requirement already satisfied: cryptography>=3.1 in /opt/homebrew/lib/python3.10/site-packages (from asyncssh<3,>=2.13.1->scmrepo<2,>=1.0.0->dvc[s3]) (40.0.2)
# Requirement already satisfied: click-repl>=0.2.0 in /opt/homebrew/lib/python3.10/site-packages (from celery<6,>=5.2.0->dvc-task<1,>=0.2.1->dvc[s3]) (0.2.0)
# Requirement already satisfied: click-didyoumean>=0.0.3 in /opt/homebrew/lib/python3.10/site-packages (from celery<6,>=5.2.0->dvc-task<1,>=0.2.1->dvc[s3]) (0.3.0)
# Requirement already satisfied: billiard<4.0,>=3.6.4.0 in /opt/homebrew/lib/python3.10/site-packages (from celery<6,>=5.2.0->dvc-task<1,>=0.2.1->dvc[s3]) (3.6.4.0)
# Requirement already satisfied: click-plugins>=1.1.1 in /opt/homebrew/lib/python3.10/site-packages (from celery<6,>=5.2.0->dvc-task<1,>=0.2.1->dvc[s3]) (1.1.1)
# Requirement already satisfied: vine<6.0,>=5.0.0 in /opt/homebrew/lib/python3.10/site-packages (from celery<6,>=5.2.0->dvc-task<1,>=0.2.1->dvc[s3]) (5.0.0)
# Requirement already satisfied: pytz>=2021.3 in /opt/homebrew/lib/python3.10/site-packages (from celery<6,>=5.2.0->dvc-task<1,>=0.2.1->dvc[s3]) (2022.6)
# Requirement already satisfied: click<9.0,>=8.0.3 in /opt/homebrew/lib/python3.10/site-packages (from celery<6,>=5.2.0->dvc-task<1,>=0.2.1->dvc[s3]) (8.1.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/homebrew/lib/python3.10/site-packages (from gitpython>3->scmrepo<2,>=1.0.0->dvc[s3]) (4.0.10)
# Requirement already satisfied: amqp<6.0.0,>=5.0.9 in /opt/homebrew/lib/python3.10/site-packages (from kombu<6,>=5.2.0->dvc-task<1,>=0.2.1->dvc[s3]) (5.1.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/homebrew/lib/python3.10/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=12->dvc[s3]) (0.1.2)
# Requirement already satisfied: PyYAML>=5.1.0 in /Users/ennmouri/Library/Python/3.10/lib/python/site-packages (from omegaconf<2.4,>=2.2->hydra-core>=1.1->dvc[s3]) (6.0)
# Requirement already satisfied: cffi>=1.9.1 in /Users/ennmouri/Library/Python/3.10/lib/python/site-packages (from pygit2>=1.10.0->scmrepo<2,>=1.0.0->dvc[s3]) (1.15.1)
# Requirement already satisfied: orjson in /opt/homebrew/lib/python3.10/site-packages (from sqltrie<1,>=0.3.1->dvc-data<0.52,>=0.51.0->dvc[s3]) (3.8.14)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/homebrew/lib/python3.10/site-packages (from aiohttp>=3.3.1->aiobotocore[boto3]>1.0.1->dvc-s3==2.22.0->dvc[s3]) (6.0.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/homebrew/lib/python3.10/site-packages (from aiohttp>=3.3.1->aiobotocore[boto3]>1.0.1->dvc-s3==2.22.0->dvc[s3]) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/homebrew/lib/python3.10/site-packages (from aiohttp>=3.3.1->aiobotocore[boto3]>1.0.1->dvc-s3==2.22.0->dvc[s3]) (1.3.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/homebrew/lib/python3.10/site-packages (from aiohttp>=3.3.1->aiobotocore[boto3]>1.0.1->dvc-s3==2.22.0->dvc[s3]) (1.9.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /opt/homebrew/lib/python3.10/site-packages (from aiohttp>=3.3.1->aiobotocore[boto3]>1.0.1->dvc-s3==2.22.0->dvc[s3]) (4.0.2)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /opt/homebrew/lib/python3.10/site-packages (from boto3<1.26.77,>=1.26.76->aiobotocore[boto3]>1.0.1->dvc-s3==2.22.0->dvc[s3]) (0.6.1)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/homebrew/lib/python3.10/site-packages (from boto3<1.26.77,>=1.26.76->aiobotocore[boto3]>1.0.1->dvc-s3==2.22.0->dvc[s3]) (1.0.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/homebrew/lib/python3.10/site-packages (from botocore<1.29.77,>=1.29.76->aiobotocore[boto3]>1.0.1->dvc-s3==2.22.0->dvc[s3]) (2.8.2)
# Requirement already satisfied: pycparser in /Users/ennmouri/Library/Python/3.10/lib/python/site-packages (from cffi>=1.9.1->pygit2>=1.10.0->scmrepo<2,>=1.0.0->dvc[s3]) (2.21)
# Requirement already satisfied: prompt-toolkit in /Users/ennmouri/Library/Python/3.10/lib/python/site-packages (from click-repl>=0.2.0->celery<6,>=5.2.0->dvc-task<1,>=0.2.1->dvc[s3]) (3.0.36)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/homebrew/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython>3->scmrepo<2,>=1.0.0->dvc[s3]) (5.0.0)
# Requirement already satisfied: wcwidth in /Users/ennmouri/Library/Python/3.10/lib/python/site-packages (from prompt-toolkit->click-repl>=0.2.0->celery<6,>=5.2.0->dvc-task<1,>=0.2.1->dvc[s3]) (0.2.6)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: python3.10 -m pip install --upgrade pip

# %% [markdown]
# ### 1. Setup IBM Cloud and COS Credentials
#
# **Note**: If you are running this notebook outside of a Watson Studio Pipeline execution. Make sure to set the environment variables that the Pipeline environment would have passed to the notebook.
# Refer to ```credentials.py```.

# %%
# Uncomment this cell and put your credentials in credentials.py to run locally.
from credentials2 import set_env_variables_for_credentials
set_env_variables_for_credentials()

# %%
## Retrieve cos credentials from global pipeline parameters
import json
# Get json from environment and convert to string
project_cos_credentials = json.loads(os.getenv('PROJECT_COS_CREDENTIALS'))
mlops_cos_credentials = json.loads(os.getenv('MLOPS_COS_CREDENTIALS'))

## PROJECT COS 
AUTH_ENDPOINT = project_cos_credentials['AUTH_ENDPOINT']
ENDPOINT_URL = project_cos_credentials['ENDPOINT_URL']
API_KEY_COS = project_cos_credentials['API_KEY']
BUCKET_PROJECT_COS = project_cos_credentials['BUCKET']

## MLOPS COS
ENDPOINT_URL_MLOPS = mlops_cos_credentials['ENDPOINT_URL']
API_KEY_MLOPS = mlops_cos_credentials['API_KEY']
CRN_MLOPS = mlops_cos_credentials['CRN']
BUCKET_MLOPS  = mlops_cos_credentials['BUCKET']

# %%
CLOUD_API_KEY = os.getenv("CLOUD_API_KEY")
DATA_FILENAME = os.getenv("serialized_data_filename")

# %%
# # @hidden_cell
# CLOUD_API_KEY = ""
# DATA_FILENAME = ""

# %%
# Secret to git repository on public git
#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

# %% [markdown]
# ## 2. Set-up DVC Situation

# %% [markdown]
# Clone a (preferably empty) git repository which will be used for data and model version tracking.<br> It will store ```.dvc``` files **and it will contain the remote locations as well as the corresponding access keys.**<br> Make sure to create a private repository or work with GitHub Enterprise.
#
# The following cells expect the repository to be empty, however they should be able to skip cells if they have already been completed. Their nature is non-overwriting.

# %% [markdown]
# #### 2.1. Clone Empty Repository for Versioning w/ DVC

# %%
# NOTE: env set in credentials.py
# !git clone $GIT_REPOSITORY
# Out:
# fatal: destination path 'dvc-testing' already exists and is not an empty directory.

# %%
# !cd dvc-testing && dvc init
# Out:
# zsh:1: /Users/ennmouri/csm/mlops-sustainability-oss/venv/bin/dvc: bad interpreter: /Users/ennmouri/csm/mlops-sustainability/venv/bin/python3: no such file or directory
# ERROR: failed to initiate DVC - '.dvc' exists. Use `-f` to force.

# %% [markdown]
# #### 2.2. Add IBM COS Instance to dvc.config as remote
#
# To successfully complete this step, make sure that you create Cloud Object Storage "Credentials" for the COS Instance that you want to use.
# <br>**Note:** Make sure to enable HMAC credentials when generating the "Credentials" in IBM Cloud.

# %%
# !cd dvc-testing && dvc remote add -d -f ibm-cos s3://mlops-sustainability-data/
# Out:
# zsh:1: /Users/ennmouri/csm/mlops-sustainability-oss/venv/bin/dvc: bad interpreter: /Users/ennmouri/csm/mlops-sustainability/venv/bin/python3: no such file or directory
# Setting 'ibm-cos' as a default remote.

# %%
# !cd dvc-testing && dvc remote modify ibm-cos endpointurl https://s3.eu-de.cloud-object-storage.appdomain.cloud
# Out:
# zsh:1: /Users/ennmouri/csm/mlops-sustainability-oss/venv/bin/dvc: bad interpreter: /Users/ennmouri/csm/mlops-sustainability/venv/bin/python3: no such file or directory

# %%
# !cd dvc-testing && dvc remote modify ibm-cos access_key_id $HMAC_ADMIN_ACCESS_KEY
# Out:
# zsh:1: /Users/ennmouri/csm/mlops-sustainability-oss/venv/bin/dvc: bad interpreter: /Users/ennmouri/csm/mlops-sustainability/venv/bin/python3: no such file or directory

# %%
# !cd dvc-testing && dvc remote modify ibm-cos secret_access_key $HMAC_ADMIN_SECRET_ACCESS_KEY
# Out:
# zsh:1: /Users/ennmouri/csm/mlops-sustainability-oss/venv/bin/dvc: bad interpreter: /Users/ennmouri/csm/mlops-sustainability/venv/bin/python3: no such file or directory

# %%
# !cd dvc-testing && git commit .dvc/config -m "Configure IBM COS (S3) as remote storage"
# Out:
# On branch main
# Your branch is ahead of 'origin/main' by 1 commit.
#   (use "git push" to publish your local commits)
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
# 	data/era5-glofas-merged.pkl.dvc
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !cd dvc-testing && dvc push
# Out:
# zsh:1: /Users/ennmouri/csm/mlops-sustainability-oss/venv/bin/dvc: bad interpreter: /Users/ennmouri/csm/mlops-sustainability/venv/bin/python3: no such file or directory
# Everything is up to date.

# %% [markdown]
# #### 2.3. Beginning tracking concatenated ERA5/GloFAS data
#
# The purpose of tracking the whole unsplitted dataset is solely for safety. We will track the train/test split data separately in a later notebook.

# %%
# !cd dvc-testing && mkdir data
# Out:
# mkdir: data: File exists

# %%
# !mv era5-glofas-merged.pkl dvc-testing/data

# %%
# !cd dvc-testing && dvc add data/era5-glofas-merged.pkl
# Out:
# zsh:1: /Users/ennmouri/csm/mlops-sustainability-oss/venv/bin/dvc: bad interpreter: /Users/ennmouri/csm/mlops-sustainability/venv/bin/python3: no such file or directory
# ⠋ Checking graph
# Adding...
# !
#   0% Checking cache in '/Users/ennmouri/csm/mlops-sustainability-oss/dvc-testing
#
# !
#   0%|          |Checking out data/era5-glofas-merged.p0/? [00:00<?,    ?files/s]
#   0%|          |Checking out data/era5-glofas-merged.p0/1 [00:00<?,    ?files/s]
# 100% Adding...|████████████████████████████████████████|1/1 [00:00, 72.04file/s]
#
# To track the changes with git, run:
#
# 	git add data/era5-glofas-merged.pkl.dvc
#
# To enable auto staging, run:
#
# 	dvc config core.autostage true

# %%
# To track the cahnges with git, run:
# !cd dvc-testing && git add data/.gitignore data/era5-glofas-merged.pkl.dvc

# %%
# !cd dvc-testing && git commit -m "Newest ERA5xGloFAS data"
# Out:
# On branch main
# Your branch is ahead of 'origin/main' by 2 commits.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean

# %%
# !cd dvc-testing && git push
# Out:
# git: 'credential-manager-core' is not a git command. See 'git --help'.
# Enumerating objects: 11, done.
# Counting objects: 100% (11/11), done.
# Delta compression using up to 8 threads
# Compressing objects: 100% (8/8), done.
# Writing objects: 100% (8/8), 1.01 KiB | 1.01 MiB/s, done.
# Total 8 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), done.
# remote: This repository moved. Please use the new location:
# remote:   https://github.com/iIias/dvc-testing.git
# To https://github.com/iiias/dvc-testing.git
#    eea259d..26fd6db  main -> main

# %%
# To enable auto staging, run:
# !dvc config core.autostage true
# Out:
# zsh:1: /Users/ennmouri/csm/mlops-sustainability-oss/venv/bin/dvc: bad interpreter: /Users/ennmouri/csm/mlops-sustainability/venv/bin/python3: no such file or directory
# ERROR: configuration error - config file error: Not inside a DVC repo

# %%
# !cd dvc-testing && git config --global user.email "ilias.ennmouri@ibm.com"
# !cd dvc-testing && git config --global user.name "Ilias Ennmouri"

# %%
# !cd dvc-testing && git add

# %%
# !cd dvc-testing && git commit -m "Add merged ERA5 and GloFas data"
# Out:
# [main 65624de] Add merged ERA5 and GloFas data
#  1 file changed, 1 insertion(+)

# %%
# !cd dvc-testing && dvc push
# Out:
# zsh:1: /Users/ennmouri/csm/mlops-sustainability-oss/venv/bin/dvc: bad interpreter: /Users/ennmouri/csm/mlops-sustainability/venv/bin/python3: no such file or directory
#   0% Transferring|                                   |0/1 [00:00<?,     ?file/s]
# !
#   0%|          |/Users/ennmouri/csm/mlops-sustainab0.00/? [00:00<?,        ?B/s]
#   0%|          |/Users/ennmouri/csm/mlops-sustai0.00/549M [00:00<?,        ?B/s]
#   9%|▉         |/Users/ennmouri/csm/mlops-s50.0M/549M [00:17<02:54,    3.00MB/s]^C
#
# ERROR: interrupted by the user

# %%
#!dvc get $GIT_REPOSITORY data/era5-glofas-merged.pkl -o data/era5-glofas-merged.pkl

# %% [markdown]
# ### 3. Hand-off to Next Pipeline Node

# %%
validation_params = {}
validation_params["tracking_merged"] = True

# %%
pipelines_client = WSPipelines.from_apikey(apikey=CLOUD_API_KEY)
pipelines_client.store_results(validation_params)
