# %% [markdown]
# # Initialize DVC and Start Tracking Merged Data

# %% [markdown]
# - Clean data
#     - Drop columns not required for training
#     - Drop rows with null valus where it makes sense
#     (river discharge may be NaN where there is no river. It makes sense to keep these rows for the model to learn where rivers are)
# - Think about whether or not to have separate notebooks for new data retrievals and prep
# - Version Control the data
# - Train test splitting
# - Version control again??

# %%
# Install required packages.
# TODO: Create IBM Cloud Software Configuration for those
# !pip install ibm-cos-sdk ibm_watson_studio_pipelines

# %%
from botocore.client import Config
from sklearn.model_selection import train_test_split
from dataclasses import dataclass
import numpy as np
import pandas as pd

from ibm_watson_studio_pipelines import WSPipelines
import ibm_boto3

import logging
import os, types
import warnings

warnings.filterwarnings("ignore")

# %%
# !pip install 'dvc[s3]' # dvc[all] alternatively, however, COS is covered by S3
# Out:
# Collecting dvc[s3]
#   Downloading dvc-2.57.3-py3-none-any.whl (439 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 439.4/439.4 kB 7.1 MB/s eta 0:00:00a 0:00:01
# Collecting colorama>=0.3.9 (from dvc[s3])
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Collecting configobj>=5.0.6 (from dvc[s3])
#   Downloading configobj-5.0.8-py2.py3-none-any.whl (36 kB)
# Collecting distro>=1.3 (from dvc[s3])
#   Downloading distro-1.8.0-py3-none-any.whl (20 kB)
# Collecting dpath<3,>=2.1.0 (from dvc[s3])
#   Downloading dpath-2.1.6-py3-none-any.whl (17 kB)
# Collecting dvc-data<0.52,>=0.51.0 (from dvc[s3])
#   Downloading dvc_data-0.51.0-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.5/61.5 kB 4.6 MB/s eta 0:00:00
# Collecting dvc-http>=2.29.0 (from dvc[s3])
#   Downloading dvc_http-2.30.2-py3-none-any.whl (12 kB)
# Collecting dvc-render<1,>=0.3.1 (from dvc[s3])
#   Downloading dvc_render-0.5.3-py3-none-any.whl (19 kB)
# Collecting dvc-studio-client<1,>=0.9.2 (from dvc[s3])
#   Downloading dvc_studio_client-0.9.2-py3-none-any.whl (10 kB)
# Collecting dvc-task<1,>=0.2.1 (from dvc[s3])
#   Downloading dvc_task-0.2.1-py3-none-any.whl (24 kB)
# Collecting flatten-dict<1,>=0.4.1 (from dvc[s3])
#   Downloading flatten_dict-0.4.2-py2.py3-none-any.whl (9.7 kB)
# Collecting flufl.lock>=5 (from dvc[s3])
#   Downloading flufl.lock-7.1.1-py3-none-any.whl (11 kB)
# Collecting funcy>=1.14 (from dvc[s3])
#   Downloading funcy-2.0-py2.py3-none-any.whl (30 kB)
# Collecting grandalf<1,>=0.7 (from dvc[s3])
#   Downloading grandalf-0.8-py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 4.6 MB/s eta 0:00:00
# Collecting hydra-core>=1.1 (from dvc[s3])
#   Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 14.5 MB/s eta 0:00:00
# Collecting iterative-telemetry>=0.0.7 (from dvc[s3])
#   Downloading iterative_telemetry-0.0.8-py3-none-any.whl (10 kB)
# Collecting networkx>=2.5 (from dvc[s3])
#   Downloading networkx-3.1-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 29.1 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: packaging>=19 in ./venv/lib/python3.9/site-packages (from dvc[s3]) (23.1)
# Collecting pathspec>=0.10.3 (from dvc[s3])
#   Downloading pathspec-0.11.1-py3-none-any.whl (29 kB)
# Requirement already satisfied: platformdirs<4,>=3.1.1 in ./venv/lib/python3.9/site-packages (from dvc[s3]) (3.5.1)
# Requirement already satisfied: psutil>=5.8 in ./venv/lib/python3.9/site-packages (from dvc[s3]) (5.9.5)
# Collecting pydot>=1.2.4 (from dvc[s3])
#   Downloading pydot-1.4.2-py2.py3-none-any.whl (21 kB)
# Collecting pygtrie>=2.3.2 (from dvc[s3])
#   Downloading pygtrie-2.5.0-py3-none-any.whl (25 kB)
# Collecting pyparsing>=2.4.7 (from dvc[s3])
#   Using cached pyparsing-3.0.9-py3-none-any.whl (98 kB)
# Requirement already satisfied: requests>=2.22 in ./venv/lib/python3.9/site-packages (from dvc[s3]) (2.30.0)
# Collecting rich>=12 (from dvc[s3])
#   Downloading rich-13.3.5-py3-none-any.whl (238 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 238.7/238.7 kB 21.3 MB/s eta 0:00:00
# Collecting ruamel.yaml>=0.17.11 (from dvc[s3])
#   Downloading ruamel.yaml-0.17.26-py3-none-any.whl (109 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.1/109.1 kB 12.2 MB/s eta 0:00:00
# Collecting scmrepo<2,>=1.0.0 (from dvc[s3])
#   Downloading scmrepo-1.0.3-py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.7/54.7 kB 5.8 MB/s eta 0:00:00
# Collecting shortuuid>=0.5 (from dvc[s3])
#   Downloading shortuuid-1.0.11-py3-none-any.whl (10 kB)
# Collecting shtab<2,>=1.3.4 (from dvc[s3])
#   Downloading shtab-1.6.1-py3-none-any.whl (13 kB)
# Collecting tabulate>=0.8.7 (from dvc[s3])
#   Using cached tabulate-0.9.0-py3-none-any.whl (35 kB)
# Collecting tomlkit>=0.11.1 (from dvc[s3])
#   Downloading tomlkit-0.11.8-py3-none-any.whl (35 kB)
# Requirement already satisfied: tqdm<5,>=4.63.1 in ./venv/lib/python3.9/site-packages (from dvc[s3]) (4.65.0)
# Collecting voluptuous>=0.11.7 (from dvc[s3])
#   Downloading voluptuous-0.13.1-py3-none-any.whl (29 kB)
# Collecting zc.lockfile>=1.2.1 (from dvc[s3])
#   Downloading zc.lockfile-3.0.post1-py3-none-any.whl (9.8 kB)
# Collecting dvc-s3==2.22.0 (from dvc[s3])
#   Downloading dvc_s3-2.22.0-py3-none-any.whl (12 kB)
# Collecting s3fs>=2022.02.0 (from dvc-s3==2.22.0->dvc[s3])
#   Downloading s3fs-2023.5.0-py3-none-any.whl (28 kB)
# Collecting aiobotocore[boto3]>1.0.1 (from dvc-s3==2.22.0->dvc[s3])
#   Downloading aiobotocore-2.5.0-py3-none-any.whl (72 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.7/72.7 kB 7.4 MB/s eta 0:00:00
# Requirement already satisfied: six in ./venv/lib/python3.9/site-packages (from configobj>=5.0.6->dvc[s3]) (1.16.0)
# Collecting dictdiffer>=0.8.1 (from dvc-data<0.52,>=0.51.0->dvc[s3])
#   Downloading dictdiffer-0.9.0-py2.py3-none-any.whl (16 kB)
# Collecting dvc-objects<1,>=0.22.0 (from dvc-data<0.52,>=0.51.0->dvc[s3])
#   Downloading dvc_objects-0.22.0-py3-none-any.whl (37 kB)
# Collecting diskcache>=5.2.1 (from dvc-data<0.52,>=0.51.0->dvc[s3])
#   Downloading diskcache-5.6.1-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.6/45.6 kB 4.2 MB/s eta 0:00:00
# Collecting nanotime>=0.5.2 (from dvc-data<0.52,>=0.51.0->dvc[s3])
#   Downloading nanotime-0.5.2.tar.gz (3.2 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: attrs>=21.3.0 in ./venv/lib/python3.9/site-packages (from dvc-data<0.52,>=0.51.0->dvc[s3]) (23.1.0)
# Collecting sqltrie<1,>=0.3.1 (from dvc-data<0.52,>=0.51.0->dvc[s3])
#   Downloading sqltrie-0.3.1-py3-none-any.whl (16 kB)
# Collecting fsspec[http] (from dvc-http>=2.29.0->dvc[s3])
#   Downloading fsspec-2023.5.0-py3-none-any.whl (160 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.1/160.1 kB 12.2 MB/s eta 0:00:00
# Collecting aiohttp-retry>=2.5.0 (from dvc-http>=2.29.0->dvc[s3])
#   Downloading aiohttp_retry-2.8.3-py3-none-any.whl (9.8 kB)
# Collecting dulwich (from dvc-studio-client<1,>=0.9.2->dvc[s3])
#   Downloading dulwich-0.21.5-cp39-cp39-macosx_11_0_arm64.whl (470 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 470.8/470.8 kB 24.9 MB/s eta 0:00:00
# Collecting celery<6,>=5.2.0 (from dvc-task<1,>=0.2.1->dvc[s3])
#   Downloading celery-5.2.7-py3-none-any.whl (405 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 405.6/405.6 kB 23.3 MB/s eta 0:00:00
# Collecting kombu<6,>=5.2.0 (from dvc-task<1,>=0.2.1->dvc[s3])
#   Downloading kombu-5.2.4-py3-none-any.whl (189 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 189.2/189.2 kB 18.2 MB/s eta 0:00:00
# Collecting atpublic>=2.3 (from flufl.lock>=5->dvc[s3])
#   Downloading atpublic-3.1.1-py3-none-any.whl (4.8 kB)
# Collecting omegaconf<2.4,>=2.2 (from hydra-core>=1.1->dvc[s3])
#   Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 8.8 MB/s eta 0:00:00
# Collecting antlr4-python3-runtime==4.9.* (from hydra-core>=1.1->dvc[s3])
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 15.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting appdirs (from iterative-telemetry>=0.0.7->dvc[s3])
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Collecting filelock (from iterative-telemetry>=0.0.7->dvc[s3])
#   Downloading filelock-3.12.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./venv/lib/python3.9/site-packages (from requests>=2.22->dvc[s3]) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.9/site-packages (from requests>=2.22->dvc[s3]) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./venv/lib/python3.9/site-packages (from requests>=2.22->dvc[s3]) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in ./venv/lib/python3.9/site-packages (from requests>=2.22->dvc[s3]) (2023.5.7)
# Collecting markdown-it-py<3.0.0,>=2.2.0 (from rich>=12->dvc[s3])
#   Downloading markdown_it_py-2.2.0-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 kB 8.8 MB/s eta 0:00:00
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./venv/lib/python3.9/site-packages (from rich>=12->dvc[s3]) (2.15.1)
# Collecting ruamel.yaml.clib>=0.2.7 (from ruamel.yaml>=0.17.11->dvc[s3])
#   Downloading ruamel.yaml.clib-0.2.7-cp39-cp39-macosx_12_0_arm64.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.8/130.8 kB 18.0 MB/s eta 0:00:00
# Collecting gitpython>3 (from scmrepo<2,>=1.0.0->dvc[s3])
#   Using cached GitPython-3.1.31-py3-none-any.whl (184 kB)
# Collecting pygit2>=1.10.0 (from scmrepo<2,>=1.0.0->dvc[s3])
#   Downloading pygit2-1.12.1-cp39-cp39-macosx_10_9_universal2.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 27.2 MB/s eta 0:00:00a 0:00:01
# Collecting asyncssh<3,>=2.13.1 (from scmrepo<2,>=1.0.0->dvc[s3])
#   Downloading asyncssh-2.13.1-py3-none-any.whl (348 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 348.5/348.5 kB 23.3 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in ./venv/lib/python3.9/site-packages (from zc.lockfile>=1.2.1->dvc[s3]) (58.0.4)
# Collecting botocore<1.29.77,>=1.29.76 (from aiobotocore[boto3]>1.0.1->dvc-s3==2.22.0->dvc[s3])
#   Downloading botocore-1.29.76-py3-none-any.whl (10.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 38.7 MB/s eta 0:00:00 0:00:01
# Collecting aiohttp>=3.3.1 (from aiobotocore[boto3]>1.0.1->dvc-s3==2.22.0->dvc[s3])
#   Using cached aiohttp-3.8.4-cp39-cp39-macosx_11_0_arm64.whl (338 kB)
# Collecting wrapt>=1.10.10 (from aiobotocore[boto3]>1.0.1->dvc-s3==2.22.0->dvc[s3])
#   Downloading wrapt-1.15.0-cp39-cp39-macosx_11_0_arm64.whl (36 kB)
# Collecting aioitertools>=0.5.1 (from aiobotocore[boto3]>1.0.1->dvc-s3==2.22.0->dvc[s3])
#   Downloading aioitertools-0.11.0-py3-none-any.whl (23 kB)
# Collecting boto3<1.26.77,>=1.26.76 (from aiobotocore[boto3]>1.0.1->dvc-s3==2.22.0->dvc[s3])
#   Downloading boto3-1.26.76-py3-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.7/132.7 kB 13.7 MB/s eta 0:00:00
# Collecting cryptography>=3.1 (from asyncssh<3,>=2.13.1->scmrepo<2,>=1.0.0->dvc[s3])
#   Downloading cryptography-40.0.2-cp36-abi3-macosx_10_12_universal2.whl (5.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 37.0 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: typing-extensions>=3.6 in ./venv/lib/python3.9/site-packages (from asyncssh<3,>=2.13.1->scmrepo<2,>=1.0.0->dvc[s3]) (4.5.0)
# Requirement already satisfied: pytz>=2021.3 in ./venv/lib/python3.9/site-packages (from celery<6,>=5.2.0->dvc-task<1,>=0.2.1->dvc[s3]) (2023.3)
# Collecting billiard<4.0,>=3.6.4.0 (from celery<6,>=5.2.0->dvc-task<1,>=0.2.1->dvc[s3])
#   Downloading billiard-3.6.4.0-py3-none-any.whl (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.5/89.5 kB 9.1 MB/s eta 0:00:00
# Collecting vine<6.0,>=5.0.0 (from celery<6,>=5.2.0->dvc-task<1,>=0.2.1->dvc[s3])
#   Downloading vine-5.0.0-py2.py3-none-any.whl (9.4 kB)
# Collecting click<9.0,>=8.0.3 (from celery<6,>=5.2.0->dvc-task<1,>=0.2.1->dvc[s3])
#   Using cached click-8.1.3-py3-none-any.whl (96 kB)
# Collecting click-didyoumean>=0.0.3 (from celery<6,>=5.2.0->dvc-task<1,>=0.2.1->dvc[s3])
#   Downloading click_didyoumean-0.3.0-py3-none-any.whl (2.7 kB)
# Collecting click-repl>=0.2.0 (from celery<6,>=5.2.0->dvc-task<1,>=0.2.1->dvc[s3])
#   Downloading click_repl-0.2.0-py3-none-any.whl (5.2 kB)
# Collecting click-plugins>=1.1.1 (from celery<6,>=5.2.0->dvc-task<1,>=0.2.1->dvc[s3])
#   Downloading click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Collecting gitdb<5,>=4.0.1 (from gitpython>3->scmrepo<2,>=1.0.0->dvc[s3])
#   Using cached gitdb-4.0.10-py3-none-any.whl (62 kB)
# Collecting amqp<6.0.0,>=5.0.9 (from kombu<6,>=5.2.0->dvc-task<1,>=0.2.1->dvc[s3])
#   Downloading amqp-5.1.1-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.8/50.8 kB 8.3 MB/s eta 0:00:00
# Collecting mdurl~=0.1 (from markdown-it-py<3.0.0,>=2.2.0->rich>=12->dvc[s3])
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Requirement already satisfied: PyYAML>=5.1.0 in ./venv/lib/python3.9/site-packages (from omegaconf<2.4,>=2.2->hydra-core>=1.1->dvc[s3]) (6.0)
# Collecting cffi>=1.9.1 (from pygit2>=1.10.0->scmrepo<2,>=1.0.0->dvc[s3])
#   Using cached cffi-1.15.1-cp39-cp39-macosx_11_0_arm64.whl (174 kB)
# Collecting orjson (from sqltrie<1,>=0.3.1->dvc-data<0.52,>=0.51.0->dvc[s3])
#   Downloading orjson-3.8.12-cp39-cp39-macosx_11_0_x86_64.macosx_11_0_arm64.macosx_11_0_universal2.whl (239 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.7/239.7 kB 23.7 MB/s eta 0:00:00
# Collecting multidict<7.0,>=4.5 (from aiohttp>=3.3.1->aiobotocore[boto3]>1.0.1->dvc-s3==2.22.0->dvc[s3])
#   Using cached multidict-6.0.4-cp39-cp39-macosx_11_0_arm64.whl (29 kB)
# Collecting async-timeout<5.0,>=4.0.0a3 (from aiohttp>=3.3.1->aiobotocore[boto3]>1.0.1->dvc-s3==2.22.0->dvc[s3])
#   Using cached async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp>=3.3.1->aiobotocore[boto3]>1.0.1->dvc-s3==2.22.0->dvc[s3])
#   Downloading yarl-1.9.2-cp39-cp39-macosx_11_0_arm64.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 8.1 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1 (from aiohttp>=3.3.1->aiobotocore[boto3]>1.0.1->dvc-s3==2.22.0->dvc[s3])
#   Using cached frozenlist-1.3.3-cp39-cp39-macosx_11_0_arm64.whl (35 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp>=3.3.1->aiobotocore[boto3]>1.0.1->dvc-s3==2.22.0->dvc[s3])
#   Using cached aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in ./venv/lib/python3.9/site-packages (from boto3<1.26.77,>=1.26.76->aiobotocore[boto3]>1.0.1->dvc-s3==2.22.0->dvc[s3]) (1.0.1)
# Collecting s3transfer<0.7.0,>=0.6.0 (from boto3<1.26.77,>=1.26.76->aiobotocore[boto3]>1.0.1->dvc-s3==2.22.0->dvc[s3])
#   Downloading s3transfer-0.6.1-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 kB 8.7 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in ./venv/lib/python3.9/site-packages (from botocore<1.29.77,>=1.29.76->aiobotocore[boto3]>1.0.1->dvc-s3==2.22.0->dvc[s3]) (2.8.2)
# Collecting pycparser (from cffi>=1.9.1->pygit2>=1.10.0->scmrepo<2,>=1.0.0->dvc[s3])
#   Using cached pycparser-2.21-py2.py3-none-any.whl (118 kB)
# Requirement already satisfied: prompt-toolkit in ./venv/lib/python3.9/site-packages (from click-repl>=0.2.0->celery<6,>=5.2.0->dvc-task<1,>=0.2.1->dvc[s3]) (3.0.38)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython>3->scmrepo<2,>=1.0.0->dvc[s3])
#   Using cached smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: wcwidth in ./venv/lib/python3.9/site-packages (from prompt-toolkit->click-repl>=0.2.0->celery<6,>=5.2.0->dvc-task<1,>=0.2.1->dvc[s3]) (0.2.6)
# Building wheels for collected packages: antlr4-python3-runtime, nanotime
#   Building wheel for antlr4-python3-runtime (pyproject.toml) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=e7952eccb3118b16e9d3296dbdfc70ce5fd8cdb55724fb5d13e570112de9c28c
#   Stored in directory: /Users/ennmouri/Library/Caches/pip/wheels/23/cf/80/f3efa822e6ab23277902ee9165fe772eeb1dfb8014f359020a
#   Building wheel for nanotime (pyproject.toml) ... done
#   Created wheel for nanotime: filename=nanotime-0.5.2-py3-none-any.whl size=2424 sha256=590628907adc2305c51e4a7fdaba3f402c453f5621451e98d18141a14f303adc
#   Stored in directory: /Users/ennmouri/Library/Caches/pip/wheels/ee/1f/7c/610bdb7d5541b98d9743c5953e32681ef35dd54fadddd347e8
# Successfully built antlr4-python3-runtime nanotime
# Installing collected packages: voluptuous, pygtrie, nanotime, funcy, dictdiffer, billiard, appdirs, antlr4-python3-runtime, zc.lockfile, wrapt, vine, tomlkit, tabulate, smmap, shtab, shortuuid, ruamel.yaml.clib, pyparsing, pycparser, pathspec, orjson, omegaconf, networkx, multidict, mdurl, fsspec, frozenlist, flatten-dict, filelock, dvc-render, dulwich, dpath, distro, diskcache, configobj, colorama, click, atpublic, async-timeout, aioitertools, yarl, sqltrie, ruamel.yaml, pydot, markdown-it-py, iterative-telemetry, hydra-core, grandalf, gitdb, flufl.lock, dvc-studio-client, dvc-objects, click-repl, click-plugins, click-didyoumean, cffi, botocore, amqp, aiosignal, s3transfer, rich, pygit2, kombu, gitpython, dvc-data, cryptography, aiohttp, celery, boto3, asyncssh, aiohttp-retry, aiobotocore, scmrepo, s3fs, dvc-task, dvc-http, dvc, dvc-s3
#   Attempting uninstall: botocore
#     Found existing installation: botocore 1.29.137
#     Uninstalling botocore-1.29.137:
#       Successfully uninstalled botocore-1.29.137
# Successfully installed aiobotocore-2.5.0 aiohttp-3.8.4 aiohttp-retry-2.8.3 aioitertools-0.11.0 aiosignal-1.3.1 amqp-5.1.1 antlr4-python3-runtime-4.9.3 appdirs-1.4.4 async-timeout-4.0.2 asyncssh-2.13.1 atpublic-3.1.1 billiard-3.6.4.0 boto3-1.26.76 botocore-1.29.76 celery-5.2.7 cffi-1.15.1 click-8.1.3 click-didyoumean-0.3.0 click-plugins-1.1.1 click-repl-0.2.0 colorama-0.4.6 configobj-5.0.8 cryptography-40.0.2 dictdiffer-0.9.0 diskcache-5.6.1 distro-1.8.0 dpath-2.1.6 dulwich-0.21.5 dvc-2.57.3 dvc-data-0.51.0 dvc-http-2.30.2 dvc-objects-0.22.0 dvc-render-0.5.3 dvc-s3-2.22.0 dvc-studio-client-0.9.2 dvc-task-0.2.1 filelock-3.12.0 flatten-dict-0.4.2 flufl.lock-7.1.1 frozenlist-1.3.3 fsspec-2023.5.0 funcy-2.0 gitdb-4.0.10 gitpython-3.1.31 grandalf-0.8 hydra-core-1.3.2 iterative-telemetry-0.0.8 kombu-5.2.4 markdown-it-py-2.2.0 mdurl-0.1.2 multidict-6.0.4 nanotime-0.5.2 networkx-3.1 omegaconf-2.3.0 orjson-3.8.12 pathspec-0.11.1 pycparser-2.21 pydot-1.4.2 pygit2-1.12.1 pygtrie-2.5.0 pyparsing-3.0.9 rich-13.3.5 ruamel.yaml-0.17.26 ruamel.yaml.clib-0.2.7 s3fs-2023.5.0 s3transfer-0.6.1 scmrepo-1.0.3 shortuuid-1.0.11 shtab-1.6.1 smmap-5.0.0 sqltrie-0.3.1 tabulate-0.9.0 tomlkit-0.11.8 vine-5.0.0 voluptuous-0.13.1 wrapt-1.15.0 yarl-1.9.2 zc.lockfile-3.0.post1

# %% [markdown]
# ### Setup IBM Cloud and COS Credentials
#
# **Note**: If you are running this notebook outside of a Watson Studio Pipeline execution. Make sure to set the environment variables that the Pipeline environment would have passed to the notebook.
# Refer to ```credentials.py```.

# %%
# Uncomment this cell and put your credentials in credentials.py to run locally.
from credentials import set_env_variables_for_credentials
set_env_variables_for_credentials()

# %%
## Retrieve cos credentials from global pipeline parameters
import json
# Get json from environment and convert to string
project_cos_credentials = json.loads(os.getenv('PROJECT_COS_CREDENTIALS'))
mlops_cos_credentials = json.loads(os.getenv('MLOPS_COS_CREDENTIALS'))

## PROJECT COS 
AUTH_ENDPOINT = project_cos_credentials['AUTH_ENDPOINT']
ENDPOINT_URL = project_cos_credentials['ENDPOINT_URL']
API_KEY_COS = project_cos_credentials['API_KEY']
BUCKET_PROJECT_COS = project_cos_credentials['BUCKET']

## MLOPS COS
ENDPOINT_URL_MLOPS = mlops_cos_credentials['ENDPOINT_URL']
API_KEY_MLOPS = mlops_cos_credentials['API_KEY']
CRN_MLOPS = mlops_cos_credentials['CRN']
BUCKET_MLOPS  = mlops_cos_credentials['BUCKET']

# %%
CLOUD_API_KEY = os.getenv("CLOUD_API_KEY")
DATA_FILENAME = os.getenv("serialized_data_filename")

# %%
# # @hidden_cell
# CLOUD_API_KEY = ""
# DATA_FILENAME = ""

# %%
# Secret to git repository on public git
#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

# %%
# @hidden_cell
# NOTE: env set in credentials.py
# !git clone $GIT_REPOSITORY
# Out:
# Cloning into 'dvc-testing'...
# git: 'credential-manager-core' is not a git command. See 'git --help'.
# remote: Enumerating objects: 21, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (16/16), done.jects:  12% (2/16)
# remote: Total 21 (delta 2), reused 21 (delta 2), pack-reused 0
# Receiving objects: 100% (21/21), done.
# Resolving deltas: 100% (2/2), done.

# %%
# !cd dvc-testing

# %%
# !cd dvc-testing && pwd
# Out:
# /Users/ennmouri/csm/mlops-sustainability/dvc-testing

# %%
# !cd dvc-testing && dvc init
# Out:
# Initialized DVC repository.
#
# You can now commit the changes to git.
#
# +---------------------------------------------------------------------+
# |                                                                     |
# |        DVC has enabled anonymous aggregate usage analytics.         |
# |     Read the analytics documentation (and how to opt-out) here:     |
# |             <https://dvc.org/doc/user-guide/analytics>              |
# |                                                                     |
# +---------------------------------------------------------------------+
#
# What's next?
# ------------
# - Check out the documentation: <https://dvc.org/doc>
# - Get help and share ideas: <https://dvc.org/chat>
# - Star us on GitHub: <https://github.com/iterative/dvc>

# %%
# !cd dvc-testing && mkdir data

# %%
# !pwd
# Out:
# /Users/ennmouri/csm/mlops-sustainability

# %%
# !dvc get $GIT_REPOSITORY data/era5-glofas-merged.pkl -o data/era5-glofas-merged.pkl
# Out:
#   0% Downloading era5-glofas-merged-05132023.pkl|    |0/1 [00:00<?,    ?files/s]
# !
#   0%|          |data/era5-glofas-merged-05132023.pk0.00/? [00:00<?,        ?B/s]
#   0%|          |data/era5-glofas-merged-051320230.00/497M [00:00<?,        ?B/s]
#   0%|          |data/era5-glofas-merged-0513816k/497M [00:00<01:08,    7.54MB/s]
#   1%|          |data/era5-glofas-merged-0514.33M/497M [00:00<00:21,    24.1MB/s]
#   1%|          |data/era5-glofas-merged-0516.02M/497M [00:00<00:27,    18.7MB/s]
#   2%|▏         |data/era5-glofas-merged-05111.9M/497M [00:00<00:18,    28.0MB/s]
#   4%|▎         |data/era5-glofas-merged-05118.6M/497M [00:00<00:12,    40.5MB/s]
#   5%|▍         |data/era5-glofas-merged-05122.5M/497M [00:00<00:12,    40.7MB/s]
#   5%|▌         |data/era5-glofas-merged-05126.4M/497M [00:00<00:12,    40.3MB/s]
#   6%|▌         |data/era5-glofas-merged-05130.3M/497M [00:00<00:12,    40.4MB/s]
#   7%|▋         |data/era5-glofas-merged-05134.2M/497M [00:01<00:11,    40.6MB/s]
#   8%|▊         |data/era5-glofas-merged-05138.1M/497M [00:01<00:11,    40.7MB/s]
#   8%|▊         |data/era5-glofas-merged-05141.9M/497M [00:01<00:12,    39.7MB/s]
#   9%|▉         |data/era5-glofas-merged-05146.0M/497M [00:01<00:11,    40.7MB/s]
#  10%|█         |data/era5-glofas-merged-05149.8M/497M [00:01<00:11,    39.5MB/s]
#  11%|█         |data/era5-glofas-merged-05154.0M/497M [00:01<00:11,    40.9MB/s]
#  12%|█▏        |data/era5-glofas-merged-05158.0M/497M [00:01<00:11,    40.7MB/s]
#  12%|█▏        |data/era5-glofas-merged-05162.0M/497M [00:01<00:11,    41.0MB/s]
#  13%|█▎        |data/era5-glofas-merged-05166.0M/497M [00:01<00:10,    41.2MB/s]
#  14%|█▍        |data/era5-glofas-merged-05169.9M/497M [00:01<00:10,    41.2MB/s]
#  15%|█▍        |data/era5-glofas-merged-05173.8M/497M [00:02<00:10,    41.1MB/s]
#  16%|█▌        |data/era5-glofas-merged-05177.6M/497M [00:02<00:10,    40.5MB/s]
#  16%|█▋        |data/era5-glofas-merged-05181.7M/497M [00:02<00:10,    41.3MB/s]
#  17%|█▋        |data/era5-glofas-merged-05185.7M/497M [00:02<00:10,    41.3MB/s]
#  18%|█▊        |data/era5-glofas-merged-05189.6M/497M [00:02<00:10,    41.2MB/s]
#  19%|█▉        |data/era5-glofas-merged-05193.6M/497M [00:02<00:10,    41.2MB/s]
#  20%|█▉        |data/era5-glofas-merged-05197.5M/497M [00:02<00:10,    41.2MB/s]
#  20%|██        |data/era5-glofas-merged-0513101M/497M [00:02<00:10,    41.1MB/s]
#  21%|██        |data/era5-glofas-merged-0513105M/497M [00:02<00:09,    41.2MB/s]
#  22%|██▏       |data/era5-glofas-merged-0513109M/497M [00:02<00:09,    41.1MB/s]
#  23%|██▎       |data/era5-glofas-merged-0513113M/497M [00:03<00:10,    39.5MB/s]
#  24%|██▎       |data/era5-glofas-merged-0513118M/497M [00:03<00:09,    41.6MB/s]
#  24%|██▍       |data/era5-glofas-merged-0513122M/497M [00:03<00:09,    41.5MB/s]
B/s]
#  99%|█████████▉|data/era5-glofas-merged-0513493M/497M [00:21<00:04,     776kB/s]
#  99%|█████████▉|data/era5-glofas-merged-0513493M/497M [00:21<00:04,     760kB/s]
#  99%|█████████▉|data/era5-glofas-merged-0513494M/497M [00:21<00:03,     938kB/s]
#  99%|█████████▉|data/era5-glofas-merged-0513494M/497M [00:22<00:03,     825kB/s]
#  99%|█████████▉|data/era5-glofas-merged-0513494M/497M [00:22<00:03,     805kB/s]
#  99%|█████████▉|data/era5-glofas-merged-0513494M/497M [00:22<00:03,     867kB/s]
#  99%|█████████▉|data/era5-glofas-merged-0513494M/497M [00:22<00:03,     722kB/s]
#  99%|█████████▉|data/era5-glofas-merged-0513494M/497M [00:22<00:02,     949kB/s]
# 100%|█████████▉|data/era5-glofas-merged-0513494M/497M [00:22<00:02,     892kB/s]
# 100%|█████████▉|data/era5-glofas-merged-0513494M/497M [00:22<00:02,     849kB/s]
# 100%|█████████▉|data/era5-glofas-merged-0513494M/497M [00:22<00:02,     869kB/s]
# 100%|█████████▉|data/era5-glofas-merged-0513494M/497M [00:22<00:02,     997kB/s]
# 100%|█████████▉|data/era5-glofas-merged-0513495M/497M [00:23<00:01,    1.69MB/s]
# 100%|█████████▉|data/era5-glofas-merged-0513495M/497M [00:23<00:01,    1.58MB/s]
# 100%|█████████▉|data/era5-glofas-merged-0513495M/497M [00:23<00:01,    1.38MB/s]
# 100%|█████████▉|data/era5-glofas-merged-0513495M/497M [00:23<00:00,    1.52MB/s]
# 100%|█████████▉|data/era5-glofas-merged-0513495M/497M [00:23<00:00,    1.84MB/s]
# 100%|█████████▉|data/era5-glofas-merged-0513496M/497M [00:23<00:00,    1.58MB/s]
# 100%|█████████▉|data/era5-glofas-merged-0513496M/497M [00:23<00:00,    1.30MB/s]
# 100%|█████████▉|data/era5-glofas-merged-0513496M/497M [00:23<00:00,    1.17MB/s]
# 100%|█████████▉|data/era5-glofas-merged-0513496M/497M [00:23<00:00,    1.05MB/s]
# 100%|█████████▉|data/era5-glofas-merged-0513496M/497M [00:24<00:00,     959kB/s]
# 100%|█████████▉|data/era5-glofas-merged-0513496M/497M [00:24<00:00,     974kB/s]
# 100%|█████████▉|data/era5-glofas-merged-0513496M/497M [00:24<00:00,     866kB/s]
# 100%|█████████▉|data/era5-glofas-merged-0513496M/497M [00:24<00:00,     859kB/s]
# 100%|█████████▉|data/era5-glofas-merged-0513496M/497M [00:24<00:00,     842kB/s]
# 100% Downloading era5-glofas-merged-05132023.pkl|█|1/1 [00:25<00:00, 25.20s/file

# %%
# !cd dvc-testing && dvc get https://github.com/iterative/dataset-registry get-started/data.xml -o data/data.xml
# Out:
#   0% Downloading data.xml|                           |0/1 [00:00<?,    ?files/s]
# !
#   0%|          |get-started/data.xml               0.00/? [00:00<?,        ?B/s]
#   0%|          |get-started/data.xml           0.00/13.8M [00:00<?,        ?B/s]
#   0%|          |get-started/data.xml      67.6k/13.8M [00:00<00:41,     347kB/s]
#   1%|          |get-started/data.xml       170k/13.8M [00:00<00:22,     638kB/s]
#   2%|▏         |get-started/data.xml       323k/13.8M [00:00<00:14,     984kB/s]
#   5%|▍         |get-started/data.xml       646k/13.8M [00:00<00:07,    1.79MB/s]
#   9%|▉         |get-started/data.xml      1.29M/13.8M [00:00<00:03,    3.50MB/s]
#  19%|█▉        |get-started/data.xml      2.68M/13.8M [00:00<00:01,    7.05MB/s]
#  38%|███▊      |get-started/data.xml      5.17M/13.8M [00:00<00:00,    13.0MB/s]
#  64%|██████▎   |get-started/data.xml      8.76M/13.8M [00:00<00:00,    20.6MB/s]
# 100% Downloading data.xml|██████████████████████|1/1 [00:02<00:00,  2.54s/files]

# %%
# !mv era5-glofas-merged.pkl dvc-testing/data

# %%
# !cd dvc-testing && ls -lh data
# Out:
# total 0

# %%
# !cd dvc-testing && dvc add data/era5-glofas-merged.pkl
# Out:
#                                                                           ⠋ Checking graph
# Adding...
# !
#   0% Checking cache in '/Users/ennmouri/csm/mlops-sustainability/dvc-testing/.dv
#
# !
#   0%|          |Transferring                          0/? [00:00<?,     ?file/s]
#   0%|          |Transferring                          0/1 [00:00<?,     ?file/s]
#
# !
#   0%|          |Checking out data/era5-glofas-merged-00/? [00:00<?,    ?files/s]
#   0%|          |Checking out data/era5-glofas-merged-00/1 [00:00<?,    ?files/s]
# 100% Adding...|████████████████████████████████████████|1/1 [00:01,  1.97s/file]
#
# To track the changes with git, run:
#
# 	git add data/.gitignore data/era5-glofas-merged-05132023.pkl.dvc
#
# To enable auto staging, run:
#
# 	dvc config core.autostage true

# %%
# To track the cahnges with git, run:
# !git add data/.gitignore data/era5-glofas-merged.pkl.dvc
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
# To enable auto staging, run:
# !dvc config core.autostage true
# Out:
# ERROR: configuration error - config file error: Not inside a DVC repo

# %%
# !ls
# Out:
# a0_retrieve_and_prepare_copernicus_data.ipynb
# a1_data_prep_and_version_control.ipynb
# assets
# dvc-testing
# era5
# era5_2023.netcdf.zip
# glofas
# glofas_2023.netcdf4.zip
# venv

# %%
# !cd dvc-testing && git config --global user.email "ilias.ennmouri@ibm.com"
# !cd dvc-testing && git config --global user.name "Ilias Ennmouri"

# %%
# !cd dvc-testing && git commit -m "Add test climate data"
# Out:
# [main (root-commit) 1b8974f] Add test climate data
#  3 files changed, 6 insertions(+)
#  create mode 100644 .dvc/.gitignore
#  create mode 100644 .dvc/config
#  create mode 100644 .dvcignore

# %%
# Add remote

# %%
# !cd dvc-testing && dvc remote add -d -f ibm-cos s3://mlops-sustainability-data/
# Out:
# Setting 'ibm-cos' as a default remote.

# %%
# !cd dvc-testing && dvc remote modify ibm-cos endpointurl https://s3.eu-de.cloud-object-storage.appdomain.cloud

# %%
# !cd dvc-testing && dvc remote modify ibm-cos access_key_id $HMAC_ADMIN_ACCESS_KEY

# %%
# !cd dvc-testing && dvc remote modify ibm-cos secret_access_key $HMAC_ADMIN_SECRET_ACCESS_KEY

# %%
# !cd dvc-testing && git commit .dvc/config -m "Try configure remote storage"
# Out:
# [main f7b96de] Try configure remote storage
#  1 file changed, 7 insertions(+)

# %%
# !cd dvc-testing && git commit .dvc/config -m "Try configure remote storage"
# Out:
# [main f7b96de] Try configure remote storage
#  1 file changed, 7 insertions(+)

# %%
# !cd dvc-testing && dvc push
# Out:
#   0% Transferring|                                   |0/1 [00:00<?,     ?file/s]
# !
#   0%|          |/Users/ennmouri/csm/mlops-sustainab0.00/? [00:00<?,        ?B/s]
#   0%|          |/Users/ennmouri/csm/mlops-sustai0.00/497M [00:00<?,        ?B/s]
#  10%|█         |/Users/ennmouri/csm/mlops-s50.0M/497M [00:10<01:30,    5.15MB/s]
#  20%|██        |/Users/ennmouri/csm/mlops-su100M/497M [00:19<01:15,    5.53MB/s]
#  30%|███       |/Users/ennmouri/csm/mlops-su150M/497M [00:28<01:04,    5.61MB/s]
#  40%|████      |/Users/ennmouri/csm/mlops-su200M/497M [00:37<00:55,    5.63MB/s]
#  50%|█████     |/Users/ennmouri/csm/mlops-su250M/497M [00:46<00:45,    5.66MB/s]
#  60%|██████    |/Users/ennmouri/csm/mlops-su300M/497M [00:56<00:36,    5.59MB/s]
#  70%|███████   |/Users/ennmouri/csm/mlops-su350M/497M [01:05<00:27,    5.63MB/s]
#  81%|████████  |/Users/ennmouri/csm/mlops-su400M/497M [01:14<00:17,    5.65MB/s]
#  91%|█████████ |/Users/ennmouri/csm/mlops-su450M/497M [01:23<00:08,    5.70MB/s]
# 100% Transferring|███████████████████████████████|1/1 [01:32<00:00, 92.76s/file]
# 1 file pushed
